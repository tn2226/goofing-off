# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels as stats

# %%
#!/usr/bin/env python
import matplotlib.mlab as mlab
from matplotlib.pyplot import figure, show
import numpy as np

plt.xkcd()

x = np.arange(0.0, 90, 0.1)
y = x
yeven = np.sin(1.15 * x) * 50
y1 = np.sin(1.15 * x) * np.exp(x**.25)  *4
y2 = np.sin(1.15 * x) * np.exp(-x**.25) *250
y3 = .9 * x + 15
y4 = np.sin(1.15 * x) * np.exp(x**.25) * .05 * x
y5 = np.sin(1.15 * x) * 50 + .9 * x + 15
y6 = np.sin(1.15 * x) * np.exp(-x**.25) *250 + .9 * x + 15
y7 = np.sin(1.15 * x) * np.exp(x**.25)  *4 + .9 * x + 15


fig, axes = plt.subplots(figsize=(10, 120), ncols=1, nrows=17)
ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10, ax11, ax12, ax13, ax14, ax15, ax16, ax17= axes.ravel()

ax1.fill_between(x, 0, y)
ax1.set_title('An ideal conception of happiness:\nAs we get older, things only get better.')
ax1.set_ylabel('happiness')
ax1.set_xlabel('age')
ax1.set_ylim(0,100)
ax1.plot(x, y, color='black')
ax1.fill_between(x, 0, y, where=y>=0, facecolor='mediumseagreen', interpolate=True)

ax2.fill_between(x, 0, yeven)
ax2.set_title('A more realistic conception of happiness?\nWe experience ups and downs. Though, perhaps in different ways,\nwith alternative dispositions.')
ax2.set_ylabel('happiness')
ax2.set_xlabel('age')
ax2.set_ylim(-100,100)
ax2.plot(x, yeven, color='black')
ax2.fill_between(x, 0, yeven, where=yeven>=0, facecolor='mediumseagreen', interpolate=True)
ax2.fill_between(x, 0, yeven, where=yeven<=0, facecolor='tomato', interpolate=True)

ax3.fill_between(x, 0, y2)
ax3.set_title('Youth-skewed happiness:\nThe best (and worst) days were in the past.')
ax3.set_ylabel('happiness')
ax3.set_xlabel('age')
ax3.set_ylim(-100,100)
ax3.plot(x, y2, color='black')
ax3.fill_between(x, 0, y2, where=y2>=0, facecolor='mediumseagreen', interpolate=True)
ax3.fill_between(x, 0, y2, where=y2<=0, facecolor='tomato', interpolate=True)

ax4.fill_between(x, 0, y1)
ax4.set_title('Mature-skewed happiness:\nThe best (and worst) days are in the future.')
ax4.set_ylabel('happiness')
ax4.set_xlabel('age')
ax4.set_ylim(-100,100)
ax4.plot(x, y1, color='black')
ax4.fill_between(x, 0, y1, where=y1>=0, facecolor='mediumseagreen', interpolate=True)
ax4.fill_between(x, 0, y1, where=y1<=0, facecolor='tomato', interpolate=True)

ax5.fill_between(x, 0, y1)
ax5.set_title('Does happiness = utility (e.g., money, property, power, status)?\nMany conflate the two even though we know that other factors matter\nsuch as relationships, aesthetics, and connections to higher causes.')
ax5.set_ylabel('utility')
ax5.set_xlabel('some state, err...not sure what to label this')
ax5.set_ylim(-100,100)
ax5.plot(x, y1, color='black')
ax5.fill_between(x, 0, y1, where=y1>=0, facecolor='lightslategrey', interpolate=True)
ax5.fill_between(x, 0, y1, where=y1<=0, facecolor='silver', interpolate=True)

ax6.fill_between(x, 0, y1)
ax6.set_title('An ideal conception of utility (monotonic preferences):\nWe always want to obtain a higher level (e.g., a better job,\nmore money, or a bigger house).')
ax6.set_ylabel('utility')
ax6.set_xlabel('some state, err...not sure what to label this')
ax6.set_ylim(0,45)
ax6.set_xlim(21.9,30)
ax6.plot(x, y1, color='black')
ax6.fill_between(x, 0, y1, where=y1>=0, facecolor='lightslategrey', interpolate=True)
ax6.fill_between(x, 0, y1, where=y1<=0, facecolor='silver', interpolate=True)

ax7.fill_between(x, 0, y1)
ax7.set_title('Push (i.e., incentives and goals) and pull (.i.e., risks and dangers)\nfactors can keep us at one steady-state equilibrium, lower or higher.\nDoes a lower equilibria mean happiness is capped? A higher equilibria,\nthat happiness is better at this state?')
ax7.set_ylabel('utility')
ax7.set_xlabel('some state, err...not sure what to label this')
ax7.set_ylim(-45,45)
ax7.set_xlim(21.9,30)
ax7.plot(x, y1, color='black')
ax7.fill_between(x, 0, y1, where=y1>=0, facecolor='lightslategrey', interpolate=True)
ax7.fill_between(x, 0, y1, where=y1<=0, facecolor='silver', interpolate=True)

ax8.plot(x,y3,color="gray",ls='--')
ax8.set_title('The hedonic treadmill:\nWhy are so many not happier at greater levels of utility?')
ax8.set_ylabel('utility')
ax8.set_ylim(0,100)
ax8.set_xlabel('some state, err...not sure what to label this')
plt.tight_layout(pad=0.4, w_pad=2.5, h_pad=2.5)

ax9.plot(x,y3,color="gray",ls='--')
ax9.set_title('The hedonic treadmill:\nSupposedly, no matter what greater level of utility we achieve, despite specious gains, and\nregardless of our efforts, we eventually end up no happier than our previous position.')
ax9.set_ylabel('utility')
ax9.set_xlabel('some state, err...not sure what to label this')
ax9.plot(x, y1, color='black')
ax9.fill_between(x, 0, y1, where=y1>=0, facecolor='lightslategrey', interpolate=True)
ax9.fill_between(x, 0, y1, where=y1<=0, facecolor='silver', interpolate=True)

ax10.plot(x,y3,color="gray",ls='--')
ax10.set_title('Treadmill: Even happiness\nHappiness and utility may exist on independent axes. Here, joy and sadness\novertake us in equal swings as a matter of course. On the treadmill, through the\nday-to-day, we experience equal swings that give us the perception of no permanent\nratcheting up, but in the end, we are actually better off than at the start.')
ax10.set_ylabel('happiness')
ax10.set_xlabel('age')
ax10.plot(x, y5, color='black')
ax10.fill_between(x, y3, y5, where=y5>=y3, facecolor='mediumseagreen', interpolate=True)
ax10.fill_between(x, y3, y5, where=y5<=y3, facecolor='tomato', interpolate=True)

ax11.plot(x,y3,color="gray",ls='--')
ax11.set_title('Treadmill: Youth-skewed happiness\nDispositions matter. In order to maintain the same level of youthful happiness,\nthe treadmill forces us to endure decades of lows and highs, but ultimately,\nwe are no more happier at the end than in the beginning. So emo.')
ax11.set_ylabel('happiness')
ax11.set_xlabel('age')
ax11.plot(x, y6, color='black')
ax11.fill_between(x, y3, y6, where=y6>=y3, facecolor='mediumseagreen', interpolate=True)
ax11.fill_between(x, y3, y6, where=y6<=y3, facecolor='tomato', interpolate=True)

ax12.plot(x,y3,color="gray",ls='--')
ax12.set_title('Treadmill: Mature-skewed happiness\nAlternatively with this disposition, similar to the even-keel disposition, happiness\ngrows over time but to much greater levels. This approximates our ideal conception.')
ax12.set_ylabel('happiness')
ax12.set_xlabel('age')
ax12.plot(x, y7, color='black')
ax12.fill_between(x, y3, y7, where=y7>=y3, facecolor='mediumseagreen', interpolate=True)
ax12.fill_between(x, y3, y7, where=y7<=y3, facecolor='tomato', interpolate=True)

ax13.plot(x,y3,color="gray",ls='--')
ax13.set_title("Treadmill: Even happiness, mature-skewed utility\nThen again, we know empirically that utility has some role to play and\nis not completely independent from happiness. So maybe utility is a factor\nthat figuratively rotates up the happiness axis around the 0 origin.")
ax13.set_ylabel('happiness/utility?')
ax13.set_xlabel('age/something else?')
ax13.plot(x, y5, color='black')
ax13.fill_between(x, y3, y5, where=y5>=y3, facecolor='mediumseagreen', interpolate=True)
ax13.fill_between(x, y3, y5, where=y5<=y3, facecolor='tomato', interpolate=True)
ax13.plot(x, y1, color='black')
ax13.fill_between(x, 0, y1, where=y1>=0, facecolor='lightslategrey', interpolate=True)
ax13.fill_between(x, 0, y1, where=y1<=0, facecolor='silver', interpolate=True)

ax14.plot(x,y3,color="gray",ls='--')
ax14.set_title('Treadmill: Youth-skewed happiness, mature-skewed utility\nFor example, those living in abject poverty become happier when their incomes rise.\nMoney and material matter, duh.')
ax14.set_ylabel('happiness/utility?')
ax14.set_xlabel('age/something else?')
ax14.plot(x, y6, color='black')
ax14.fill_between(x, y3, y6, where=y6>=y3, facecolor='mediumseagreen', interpolate=True)
ax14.fill_between(x, y3, y6, where=y6<=y3, facecolor='tomato', interpolate=True)
ax14.plot(x, y1, color='black')
ax14.fill_between(x, 0, y1, where=y1>=0, facecolor='lightslategrey', interpolate=True)
ax14.fill_between(x, 0, y1, where=y1<=0, facecolor='silver', interpolate=True)

ax15.plot(x,y3,color="gray",ls='--')
ax15.set_title('Treadmill: Mature-skewed happiness, mature-skewed utility\nThough, on the other hand, we also know that there are limits. Studies show that a\nmillionaire is no happier than someone earning $70k per year. So here, it seems counterintuitive\nto hold that over time we need more and more stuff to elevate our disposition.')
ax15.set_xlabel('age/something else?')
ax15.set_ylabel('happiness/utility?')
ax15.plot(x, y7, color='black')
ax15.fill_between(x, y3, y7, where=y7>=y3, facecolor='mediumseagreen', interpolate=True)
ax15.fill_between(x, y3, y7, where=y7<=y3, facecolor='tomato', interpolate=True)
ax15.plot(x, y1, color='black')
ax15.fill_between(x, 0, y1, where=y1>=0, facecolor='lightslategrey', interpolate=True)
ax15.fill_between(x, 0, y1, where=y1<=0, facecolor='silver', interpolate=True)


ax16.set_title('Problematizing the problem:\nI should note somewhere, so why not here, that the incline of the treadmill\n(i.e., the line that divides the red and green) is arbitrarily drawn as linear\n(as opposed to say, log n or exponential) and that some inclines may be less\nor maybe some folks never get on the treadmill and are always happy. Also,\nthere is no necessity in a cyclical portrayal of happiness dispositions.\nNor need there be a one-to-one correspondence between utility\nstates and age. This all is starting to make my brian hurt, and my\ncharting skillz need werk. In anycase, others have done a much better,\nsuccinct job on this topic...')
ax16.set_xticks([])
ax16.set_yticks([])
ax16.axis('off')


ax17.set_title('Joy Division')
ax17.set_xlabel('Unknown Pleasures')
ax17.set_axis_bgcolor('black')
#this is a modification of animation example code: unchained.py, available at http://matplotlib.org/examples/animation/unchained.html
import matplotlib.animation as animation
# Add a subplot with no frame
# ax22 = plt.subplot(111, frameon=False)

# Generate random data
data = np.random.uniform(0, 1.5, (65, 70))
X = np.linspace(-1, 1, data.shape[-1])
G = 1.5 * np.exp(-4 * X * X)

# Generate line plots
lines = []
for i in range(len(data)):
    # Small reduction of the X extents to get a cheap perspective effect
    xscale = 1 - i / 200.
    # Same for linewidth (thicker strokes on bottom)
    lw = 1.5 - i / 100.0
    line, = ax17.plot(xscale * X, i + G * data[i], color="w")
    lines.append(line)

# Set y limit (or first line is cropped because of thickness)
ax17.set_ylim(-1, 50)

# No ticks
ax17.set_xticks([])
ax17.set_yticks([])



def update(*args):
    # Shift all data to the right
    data[:, 1:] = data[:, :-1]

    # Fill-in new values
    data[:, 0] = np.random.uniform(0, 1, len(data))

    # Update data
    for i in range(len(data)):
        lines[i].set_ydata(i + G * data[i])

    # Return modified artists
    return lines

# Construct the animation, using the update function as the animation
# director.
anim = animation.FuncAnimation(fig, update, interval=10)


plt.figtext(.5,1.01,'Perambulations on happiness, utility maximization, multiple\nsteady-state equilibria, and the hedonic treadmill with\nparallel, perilous adventures in matplotlib and trigonometry', fontsize=22, weight='bold', horizontalalignment ='center')
plt.figtext(0.99, 0,'t.nguyen', alpha=.8, fontsize=10, style='italic', horizontalalignment='right')
plt.tight_layout(pad=0.4, w_pad=2.5, h_pad=2.5)

plt.savefig('joydivision.png', format='png', dpi=100, bbox_inches='tight')
plt.show()

# %%
"""
Comparative path demonstration of frequency from a fake signal of a pulsar.
(mostly known because of the cover for Joy Division's Unknown Pleasures)

Author: Nicolas P. Rougier
"""
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# Create new Figure with black background
fig = plt.figure(figsize=(8, 8), facecolor='black')

# Add a subplot with no frame
ax = plt.subplot(111, frameon=False)

# Generate random data
data = np.random.uniform(0, 1.5, (65, 70))
X = np.linspace(-1, 1, data.shape[-1])
G = 1.5 * np.exp(-4 * X * X)

# Generate line plots
lines = []
for i in range(len(data)):
    # Small reduction of the X extents to get a cheap perspective effect
    xscale = 1 - i / 200.
    # Same for linewidth (thicker strokes on bottom)
    lw = 1.5 - i / 100.0
    line, = ax.plot(xscale * X, i + G * data[i], color="w", lw=.2)
    lines.append(line)

# Set y limit (or first line is cropped because of thickness)
ax.set_ylim(-1, 70)

# No ticks
ax.set_xticks([])
ax.set_yticks([])


def update(*args):
    # Shift all data to the right
    data[:, 1:] = data[:, :-1]

    # Fill-in new values
    data[:, 0] = np.random.uniform(0, 1, len(data))

    # Update data
    for i in range(len(data)):
        lines[i].set_ydata(i + G * data[i])

    # Return modified artists
    return lines

# Construct the animation, using the update function as the animation
# director.
anim = animation.FuncAnimation(fig, update, interval=10)
plt.show()
